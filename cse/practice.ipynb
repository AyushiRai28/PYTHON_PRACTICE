# %%
#write a program to find avg of n number of inputs

def avg(n):
    s = 0
    for i in range(0,n+1):

       a = int(input("enter number:"))
       s = s + a

    avg = s/n 

print("avg")    

avg(5)

# %%
def ps(n):
    if type(n**0.5)== int:
        print("True")
    else:
        print("False") 
ps(25)
# Out:
# False

# %%
# AVERAGE

def average(*n):
    sum = 0
    for i  in n:
        sum = sum + i
    avg = sum / len(n)
    return(avg)

print(average(10,10,10))

# %%
# write a program in python to convert input text into  a number using the following encoding technique
# A TO M --> 0
# N TO Z --> 1

# n = input("enter the word:")
# list1= [n]
# for i in n:

#     if n.lower ==' abcdefghijklm':
#        i = 0
#     else:
#         i = 1   
# print (list1)
l1 = [ 'A', 'B', 'C', 'D', 'E', 'F', 'G','H', 'I', 'J', 'K', 'L', 'M' ]
l2 = [ 'N', 'O', 'P','Q', 'R', 'S', 'T', 'U', 'V', 'W', 'X', 'Y','Z' ]
n = input("Enter the string: ")
encode_name = str()
for i in n:
    if i  in l1:
        encode_name = encode_name + '0'

    
    elif i in l2  :
       encode_name = encode_name + '1'
    else :
        encode_name = encode_name + i

print(encode_name)
# Out:
# Enter the string:  QSDCCHUIHJDTYOK
# 110000100001110

# %%
#write a program ro print first five toppers , avg of class and number of fai; students for in subjjsct for 10 student
def avg():

    i=1
    t=i
    a=[ '0','0','0','0','0']
    while i<5:
        a[i] = int(input(f"Enter marks for roll no. {i} :"))
        i = i +1
        

    print(a)
    sum=0
    for i in a:

        sum = sum + int(a[i])
    avg = sum/5
    print(avg)

    topper =[]
    i=t
    while i<=5:
        if a[i]>a[i+1]:
            max = a[i]
        else:
            max=a[i+1] 
        topper.append(max)    

        a.pop(max)   
        
        if a[i]>a[i+1]:
            max1 = a[i]
        else:
            max1=a[i+1] 
            topper.append(max1)
        a.pop(max1)

        
        if a[i]>a[i+1]:
            max2 = a[i]
        else:
            max2=a[i+1] 
        topper.append(max2)        
        a.pop(max2)   
        if a[i]>a[i+1]:
            max3 = a[i]
        else:
            max3=a[i+1]  
        topper.append(max3)       
        a.pop(max3)   
        if a[i]>a[i+1]:
            max4 = a[i]
        else:
            max4=a[i+1]  
            topper.append(max4)   
        a.pop(max4)   
        
   
    print(f"LIST OF TOPPERS IS {topper}")            




avg()

# %%
list1 = ['1','2','3','4','5','6','7']

#insert 10 to thirsd index without any build in function

# def insert(n):
#     v = int(input("enter new variable : "))
    
#     i=n+1

#     while i<len(list1):
#         list1[i-1] = list1[i]
#         i = i+1
#     list1[n] = v    

#     print(list1)  

#insert(3)    



def insert(data,index,value):
    j = len(data)
    data = data + list([j])

    while j>index:
        data[j]=data[j-1]
        j = j-1
    data[index]=value
    return(data)
