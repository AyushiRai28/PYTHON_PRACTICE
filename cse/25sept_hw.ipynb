# %%
#print nos divisible by 5 but not 10

n=int(input("Enter the number till which you want numbers divisible by 5 but not 10:"))
i=1
a=1
s=0
while a<=n:
    s=i*5
    i=i+2
    a=a+1
    print(s)
# Out:
# Enter theer number till which you want numbers divisible by 5 but not 10: 5
# 5
# 15
# 25
# 35
# 45

# %%
#print fibonacci series :0 ,1 ,1 ,2 ,3 ,5 ,8 ,13...

n=int(input("enter the number till which you want your fibonacci series"))
i=0
a=0
b=1
sum=0
print(0)
print(1)

while sum<n:
    sum=a+b
    print(sum)
    a=b
    b=sum
# Out:
# enter the number till which you want your fibonacci series 13
# 0
# 1
# 1
# 2
# 3
# 5
# 8
# 13

# %%
#write a program to find the factors of a number
n=int(input("enter the number you want the factors of:"))
i=1
while i<=n:
    if n%i==0:
        print(i)
    i=i+1
# Out:
# enter the number you want the factors of: 36
# 1
# 2
# 3
# 4
# 6
# 9
# 12
# 18
# 36

# %%
#check for prime number

n=int(input("enter the  number:"))
for i in range(2,n):
    if(n%i==0):
        print("Not a prime number.")
        break
    
else:
     print("it is a prime number")
# Out:
# enter the  number: 2
# it is a prime number

# %%
#check for perfect number
n=int(input("enter the number:")) 
s=n**0.5 
for i in (2,n): 
    
    if(s%i==0):
        print("perfect sqaure") 
        break
        
else: print("not a perfect square")
# Out:
# enter the number: 23
# not a perfect square

# %%
#program to print prime numbers in a range
n=int(input("enter the number:"))
i=1
def prime(n):
    for i in range(2 ,n):
        if n%i==0:
            return false
        return true    

def print_prime(n):
    count=0
    n=2

while count<n:
    if prime(n):
        print(n, end="")
        count +=1
        n +=1
# Out:
# enter the number: 4
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 14
#      11     count=0
#      12     n=2
# ---> 14 while count<n:
#      15     if prime(n):
#      16         print(n, end="")
#
# NameError: name 'count' is not defined
