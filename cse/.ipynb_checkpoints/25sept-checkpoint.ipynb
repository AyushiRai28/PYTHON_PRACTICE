# %%
n=int(input("enter number:"))
i=1
sum=0
while i<=n:
    sum=sum+i
    i=i+1
print("sum is:", sum)
# Out:
# enter number: 23
# sum is: 276

# %%
n = int(input("enter the number: "))
i = 1
fact = 1

for i in range(1,n+1):
    fact=fact*i
    i = i+1
print(" factorial of n is:", fact)
# Out:
# enter the number:  0
#  factorial of n is: 1

# %%
n = int(input("enter the number:"))
sum=0
count=0
while n>0:
    r=n%10
    sum=sum+r
    n=n//10
    count=count+1
print("sum of digits",sum)
print("no of digit", count)
# Out:
# enter the number: 12
# sum of digits 3
# no of digit 2

# %%
n=int(input("enter the number:"))
sum=0
i=1
count=0
temp=n
while n>0:
    n=n//10
    count=count+1


n=temp
while n>0:
    r=n%10
    sum=sum+r*10**(count-i)
    n=n//10
    i=i+1
print("reverse of number is",sum)
# Out:
# enter the number: 34
# reverse of number is 43

# %%
#vheck if armstrong number : number is equal to the sum of its  own digit each raised to the powerof the total number of digit
n=int(input("enter number:"))
count=0
s=0
t=n
while n>0:
    n=n//10
    count=count+1
    
n=t    
while n>0:
    r=n%10
    s=s+r**(count)
    n=n//10
print("sum of its  own digit each raised to the powerof the total number of digit:",s)

if(t==s):
    print("It is a armstrong number")
else:
    print("It is not a armstrong number")
# Out:
# enter number: 12
# sum of its  own digit each raised to the powerof the total number of digit: 5
# It is not a armstrong number
