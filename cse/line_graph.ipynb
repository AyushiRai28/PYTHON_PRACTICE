# %%
import matplotlib.pyplot as plt



x = [1, 2, 3, 4, 5, 6, 7, 8]
y = [3, 7, 13, 21, 31, 43, 57, 73]

plt.plot(x,y, marker="1")

plt.title("My first line graph")
plt.xlabel(" x axis")
plt.ylabel(" y axis")
plt.show()
