# %%
'''Prepare a python program to read five numbers and display them on the Screen.

Prepare a python program to read five numbers in to a list.

For a list created in 2, write a python program to find the presence of given number.

Prepare a python program to check whether the given two tuples are same or not.

Prepare a python program to navigate the elements in the list.'''

# %%
l = [2,3,4,5,6]
print(l[2])
a = int(input("enter the number :"))
if a in l :
        print("true")
else:
        print("false")
# Out:
# 4
# enter the number : 9
# false

# %%
s = "hello"
print(id(s))
# Out:
# 2496187374336
