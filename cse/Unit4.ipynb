# %%
n = float(input(" Enter number:"))

def newton_sqrt(n):
    x = n/2
    while True :
        print("calculating new estimate value")
        new = 0.5*(x + n/x)
        if new==x:
            print("sqaure root is", new)
            break
        
        print("new estimate is" , new)
        x = new
newton_sqrt(n)
# Out:
#  Enter number: 81
# calculating new estimate value
# new estimate is 21.25
# calculating new estimate value
# new estimate is 12.530882352941177
# calculating new estimate value
# new estimate is 9.497456198181656
# calculating new estimate value
# new estimate is 9.01302783945225
# calculating new estimate value
# new estimate is 9.000009415515176
# calculating new estimate value
# new estimate is 9.000000000004924
# calculating new estimate value
# new estimate is 9.0
# calculating new estimate value
# sqaure root is 9.0

# %%
#program to find prime factors

n = int(input("Enter number:"))
def prime(n):
    prime_list=[]
    for i in range(2, int(num/2)):
        for j in range(2,i):
            if i%j ==0:
                break
            else:
                prime_list.append(i)
    return prime_list
l = prime(n)
prime_factor = []
for x in l:
    if n%x==0:
        prime_factor.append(x)
print("prime factors of the given number", prime_factor)
ans = 1
for i in prime_factor:
    count = 0
    while n%i==0:
        count +=1
        n = n//i
    for j in range(count//2):
        ans = ans*i
print("root =", ans)

# %%
# generating factors
n = int(input("Enter a number:"))

def fac(n):
    l = []        
    i = 2
    while i<= n:
        if n%i==0:
             l.append(i)
        i += 1  
    return l    
fac(n)

# %%
#prime factors
n =  int(input("enter a number:"))

def p_fac(n):
    l = []
    if n%2==0:
        l.append(2)
    i = 3
    while (i*i<=n):
        if n%i==0:
            l.append(i)
        i+=2
    return l
p_fac(68)
