# %%
# decimal to bunary
n = int(input("enter the number:"))
i = 0
b = 0
while n>0:
   r= n%2
   b = b + (r*10**i)
   i = i+1
   n = int(n/2)
print(b)
# Out:
# enter the number: 15
# 1111

# %%
#decimal to binary
def binary(n):
    sum=0
    i=0
    while n>0:
        r = n%2
        sum = sum + (r*10**i)
        i = i+1
        n = int(n/2)
    return sum        
binary(15)
# Out:
# 1111

# %%
# binary to decimal
def decimal(b):
    sum = 0
    count = 0
    while b>0:
       r=b%10
       sum=sum+ (r*2**count)
       count = count+1
       b= int(b/10)
    return sum
decimal(1111)
# Out:
# 15

# %%
# decimal to hexa
def hexa(n):
    sum=0
    i=0
    while n>0:
        r = n%16
        for r in range(10 ,16):
            if r==10:
                10 == A
                sum = Sum + str("A")
            elif r==11:
                sum = sum + B
            elif r==12:
                sum = sum + C
            elif r==13:
                sum = sum + D
            elif r==14:
                sum = sum + E
            elif r==15:
                sum = sum + F
        sum = sum + (r*10**i)
        i = i+1
        n = int(n/16)
    return sum        
hexa(3340)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 25
#      23         n = int(n/16)
#      24     return sum
# ---> 25 hexa(3340)
#
# Cell In[36], line 9, in hexa(n)
#       7 for r in range(10 ,16):
#       8     if r==10:
# ----> 9         10 == A
#      10         sum = Sum + str("A")
#      11     elif r==11:
#
# NameError: name 'A' is not defined
